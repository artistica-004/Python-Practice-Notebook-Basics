# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
name="Shivani Chaudhary"
print("My name is", name)

#or
print("My name is " + name)

#or
print(f"My name is {name}")
# Out:
# My name is Shivani Chaudhary
# My name is Shivani Chaudhary
# My name is Shivani Chaudhary

# %%
a=10
b=3
print("The sum of a and b is", a+b)
print("The difference of a and b is", a-b)
print("The product of a and b is", a*b)
print("The quotient of a and b is", a/b)
# Out:
# The sum of a and b is 13
# The difference of a and b is 7
# The product of a and b is 30
# The quotient of a and b is 3.3333333333333335

# %%
a=10
b=86.80
c=True
d="Shivani"
print(type(a))
print(type(b))                                              
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>

# %%
name = input("What is your name? ")
age = input("What is your age? ")
print("Hello, " + name + "! Welcome to Python programming.")
print("You are " + age + " years old.")

#or
print(f"Hello {name}, you are {age} years old. Welcome to Python programming!")
# Out:
# Hello, shivani! Welcome to Python programming.
# You are 22 years old.
# Hello shivani, you are 22 years old. Welcome to Python programming!

# %%
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))              
sum = num1 + num2
difference = num1 - num2
product = num1 * num2
print("The sum of", num1, "and", num2, "is", sum)
print("The difference of", num1, "and", num2, "is", difference)
print("The product of", num1, "and", num2, "is", product)
# Out:
# The sum of 5 and 5 is 10
# The difference of 5 and 5 is 0
# The product of 5 and 5 is 25

# %%
length = float(input("Enter the length of the rectangle: "))
width = float(input("Enter the width of the rectangle: "))
area = length * width
perimeter = 2 * (length + width)
print("The area of the rectangle is", area)
print("The perimeter of the rectangle is", perimeter)
# Out:
# The area of the rectangle is 182.0
# The perimeter of the rectangle is 54.0

# %%
farenheit = float(input("Enter the temperature in Fahrenheit: "))
celsius = (farenheit - 32) * 5.0/9.
print(f"{farenheit} degrees Fahrenheit is equal to {celsius} degrees Celsius.")

celsius = float(input("Enter the temperature in Celsius: "))
farenheit = (celsius * 9.0/5.) + 32
print(f"{celsius} degrees Celsius is equal to {farenheit} degrees Fahrenheit.")
# Out:
# 22.0 degrees Fahrenheit is equal to -5.555555555555555 degrees Celsius.
# 33.0 degrees Celsius is equal to 91.4 degrees Fahrenheit.

# %%
a=10
b=20
a,b=b,a
print("The value of a is", a)
print("The value of b is", b)
# Out:
# The value of a is 20
# The value of b is 10

# %%
dist=int(input("Enter the distance in kilometers: "))
time=int(input("Enter the time in hours: "))
speed=dist/time
time=500/speed
print("The speed of the car is", speed, "km/h")
# Out:
# The speed of the car is 2.0454545454545454 km/h

# %%
pip install Math
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement Math (from versions: none)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for Math

# %%
import math

r=float(input("Enter the radius of the circle: "))
area=math.pi*r**2
print("The area of the circle is", area)
circumference=2*math.pi*r
print("The circumference of the circle is", circumference)
diameter=2*r
print("The diameter of the circle is", diameter)
# Out:
# The area of the circle is 50.26548245743669
# The circumference of the circle is 25.132741228718345
# The diameter of the circle is 8.0

# %%
bill=float(input("Enter the total bill amount: "))
tip_percentage=float(input("Enter the tip percentage you want to give: "))
tip_amount = bill * (tip_percentage / 100)
total_amount = bill + tip_amount
each_person = total_amount / 2
print(f"Each person should pay: {each_person:.2f}")
# Out:
# Each person should pay: 2950.00
